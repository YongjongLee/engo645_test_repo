# %%
print("hello ENGO Students!")
# Out:
# hello ENGO Students!

# %%
print("I am yongjong Lee")
# Out:
# I am yongjong Lee

# %%
print("just call me YJ!!")
# Out:
# just call me YJ!!

# %%
print("I'm really happy to meet you!")
# Out:
# I'm really happy to meet you!

# %%
print("Thank you!")
# Out:
# Thank you!

# %%
print("^^")
# Out:
# ^^
